# %%
# !pip install pyscipopt
# Out:
# Requirement already satisfied: pyscipopt in /usr/local/lib/python3.11/dist-packages (5.2.1)

# %%
#using SCIP solver
import pyscipopt

def bin_packing_solver(item_sizes, bin_capacity):
    model = pyscipopt.Model("BinPacking")

    #binary variables for item-bin combo
    num_items = len(item_sizes)
    total_weight = sum(item_sizes)
    max_bins = (total_weight // bin_capacity) + 1
    vars = {}

    for i in range(num_items):
        for b in range(max_bins):
            vars[i, b] = model.addVar(vtype="B", name=f"x_{i}_{b}")

    #Objective- to minimize the number of bins used
    bin_used = [model.addVar(vtype="B", name=f"bin_{b}") for b in range(max_bins)]
    model.setObjective(sum(bin_used), "minimize")

    #Each item must be in exactly one bin
    for i in range(num_items):
        model.addCons(sum(vars[i, b] for b in range(max_bins)) == 1)

    #total size of items in each bin cannot exceed bin capacity
    for b in range(max_bins):
        model.addCons(sum(vars[i, b] * item_sizes[i] for i in range(num_items)) <= bin_capacity * bin_used[b])

    model.setParam('limits/time', 600)
    model.setParam('parallel/maxnthreads', 4)
    model.relax()
    model.optimize()

    #solution from SCIP
    if model.getStatus() == "optimal":
        print("Optimal solution found!")
        solution = {}
        for b in range(max_bins):
            if model.getVal(bin_used[b]) > 0.5:#checking if the bin is used
                solution[b] = [i for i in range(num_items) if model.getVal(vars[i, b]) > 0.5]
        return solution
    else:
        print("No optimal solution found.")
        return None

# %%
item_sizes = [5, 7, 8, 3, 2]
bin_capacity = 10

result = bin_packing_solver(item_sizes, bin_capacity)
if result:
    for bin_num, items in result.items():
        print(f"Bin {bin_num}: Items {items}")
# Out:
# Optimal solution found!
# Bin 0: Items [0, 3]
# Bin 1: Items [1, 2]

# %%
item_sizes = [5, 8, 2, 5, 9]
bin_capacity = 10

result = bin_packing_solver(item_sizes, bin_capacity)
if result:
    for bin_num, items in result.items():
        print(f"Bin {bin_num}: Items {items}")
# Out:
# Optimal solution found!
# Bin 0: Items [4]
# Bin 1: Items [0, 1]
# Bin 2: Items [2, 3]

# %%
#first-fit deacreasing heuristic- offline

def first_fit_dec(n,c,l):
    bin_count = 0
    bins = [0]*n #worst case each item in separate bin
    bin_id=[0]*n
    l.sort(reverse=True)
    print(l)
    for i in range(n):
        curr = 0
        while(curr < bin_count):
            if (bins[curr] >= l[i]):
                bins[curr] = bins[curr]-l[i]
                break
            curr+=1

        if (curr == bin_count):
            bins[bin_count] = c - l[i]
            bin_count+=1
        bin_id[i]=curr

    return bin_count, bin_id

# %%
# t=int(input())

# for x in range(t):
#     n,c=map(int,input().split())
#     l=list(map(int,input().split()))
#     sol,bin_res=first_fit_dec(n,c,l)
#     print(sol)
#     print(bin_res)
# Out:
# 1
# 5 10
# 5 8 2 5 9
# [9, 8, 5, 5, 2]
# 3
# [0, 1, 2, 2, 1]

# %%
#using heuristic solution from ffd as a start for the lp
def bin_packing_ffd(item_sizes, bin_capacity, ffd_val,ffd_sol):
    model = pyscipopt.Model("BinPacking")

    #binary variables for item-bin combo
    num_items = len(item_sizes)
    total_weight = sum(item_sizes)
    max_bins = (total_weight // bin_capacity) + 1
    vars = {}

    for i in range(num_items):
        for b in range(max_bins):
            vars[i, b] = model.addVar(vtype="B", name=f"x_{i}_{b}")

    #Objective- to minimize the number of bins used
    bin_used = [model.addVar(vtype="B", name=f"bin_{b}") for b in range(max_bins)]
    model.setObjective(sum(bin_used), "minimize")

    #Each item must be in exactly one bin
    for i in range(num_items):
        model.addCons(sum(vars[i, b] for b in range(max_bins)) == 1)

    #total size of items in each bin cannot exceed bin capacity
    for b in range(max_bins):
        model.addCons(sum(vars[i, b] * item_sizes[i] for i in range(num_items)) <= bin_capacity * bin_used[b])

    #using ffd as a start
    if ffd_val and len(ffd_sol) == 2:
        n, item_to_bin = ffd_sol
        if n > 0 and len(i) == num_items:
            for i in range(num_items):
                vars[i, item_to_bin[i]].setInitialValue(1)
            for b in range(n):
                bin_used[b].setInitialValue(1)


    model.setParam('limits/time', 600)
    model.setParam('parallel/maxnthreads', 4)
    model.relax()
    model.optimize()

    #solution from SCIP
    if model.getStatus() == "optimal":
        print("Optimal solution found!")
        solution = {}
        for b in range(max_bins):
            if model.getVal(bin_used[b]) > 0.5:#checking if the bin is used
                solution[b] = [i for i in range(num_items) if model.getVal(vars[i, b]) > 0.5]
        return solution
    else:
        print("No optimal solution found.")
        return None

# %%
import os

def read_bpp(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Extract number of items and bin capacity from the first two lines
    n = int(lines[0].strip())           # Number of items
    c = int(lines[1].strip())           # Bin capacity

    # Extract item weights from the remaining lines
    weights = [int(line.strip()) for line in lines[2:]]

    if len(weights) != n:
        raise ValueError(f"Mismatch")
    return n, c, weights


def read_all():
    base_dir = '/content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U'
    file_prefix = 'Falkenauer_u250_'
    file_count = 20

    bpp_data = {}

    for i in range(file_count):
        file_name = f"{file_prefix}{str(i).zfill(2)}.txt"
        file_path = os.path.join(base_dir, file_name)

        if os.path.exists(file_path):
            print(f"Reading file: {file_path}")
            n, c, weights = read_bpp(file_path)
            bpp_data[file_name] = {'n': n, 'capacity': c, 'weights': weights}
        else:
            print(f"File not found: {file_path}")

    return bpp_data

# %%
data = read_all()
# Out:
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_00.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_01.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_02.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_03.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_04.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_05.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_06.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_07.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_08.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_09.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_10.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_11.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_12.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_13.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_14.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_15.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_16.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_17.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_18.txt
# Reading file: /content/drive/MyDrive/Falkenauer/Falkenauer/Falkenauer_U/Falkenauer_u250_19.txt

# %%
for file_name,file_data in data.items():
  print(f"{file_name}")
  c=file_data['capacity']
  #print(f"Item weights: {file_data['weights']}")
  b=file_data['weights']
  result = bin_packing_solver(b, c)
  if result:
    for bin_num, items in result.items():
        print(f"Bin {bin_num}: Items {items}")
  print()
# Out:
# Falkenauer_u250_00.txt
# Optimal solution found!
# Bin 0: Items [15]
# Bin 1: Items [83]
# Bin 2: Items [236]
# Bin 3: Items [16, 214]
# Bin 4: Items [26, 235]
# Bin 5: Items [21]
# Bin 6: Items [108]
# Bin 7: Items []
# Bin 8: Items [24, 109]
# Bin 9: Items [72, 104]
# Bin 10: Items [144]
# Bin 11: Items [222]
# Bin 12: Items []
# Bin 13: Items [112]
# Bin 14: Items []
# Bin 15: Items []
# Bin 16: Items []
# Bin 17: Items [199]
# Bin 18: Items [38]
# Bin 19: Items [85]
# Bin 20: Items [17]
# Bin 21: Items [75]
# Bin 22: Items [31, 106]
# Bin 23: Items []
# Bin 24: Items [27, 215]
# Bin 25: Items [32]
# Bin 26: Items [35, 224]
# Bin 27: Items []
# Bin 28: Items [14]
# Bin 29: Items [28, 237]
# Bin 30: Items []
# Bin 31: Items [23]
# Bin 32: Items [70]
# Bin 33: Items [34]
# Bin 34: Items []
# Bin 35: Items [121]
# Bin 36: Items [36]
# Bin 37: Items [73]
# Bin 38: Items [76, 245]
# Bin 39: Items [81, 231]
# Bin 40: Items [45, 153]
# Bin 41: Items [20]
# Bin 42: Items [213]
# Bin 43: Items [52]
# Bin 44: Items [111]
# Bin 45: Items [123]
# Bin 46: Items [25]
# Bin 47: Items [47]
# Bin 48: Items [71]
# Bin 49: Items []
# Bin 50: Items [113, 223]
# Bin 51: Items [110]
# Bin 52: Items [107]
# Bin 53: Items [48]
# Bin 54: Items [244]
# Bin 55: Items [105]
# Bin 56: Items [29, 156]
# Bin 57: Items [60]
# Bin 58: Items []
# Bin 59: Items [93, 216]
# Bin 60: Items [125]
# Bin 61: Items [74]
# Bin 62: Items [124, 160]
# Bin 63: Items [84]
# Bin 64: Items []
# Bin 65: Items [185, 200]
# Bin 66: Items [120, 169]
# Bin 67: Items [122]
# Bin 68: Items [92]
# Bin 69: Items []
# Bin 70: Items [49]
# Bin 71: Items [145, 246]
# Bin 72: Items [79, 208]
# Bin 73: Items [134]
# Bin 74: Items [96, 162, 225]
# Bin 75: Items [102, 103]
# Bin 76: Items [19]
# Bin 77: Items [33]
# Bin 78: Items [39]
# Bin 79: Items [165, 186]
# Bin 80: Items [30, 184, 248]
# Bin 81: Items [51, 163, 207]
# Bin 82: Items [82, 97]
# Bin 83: Items [243]
# Bin 84: Items [148]
# Bin 85: Items [53]
# Bin 86: Items [61]
# Bin 87: Items [154]
# Bin 88: Items [147, 166]
# Bin 89: Items [62, 164, 247]
# Bin 90: Items [22, 155]
# Bin 91: Items [146]
# Bin 92: Items [140, 159, 189]
# Bin 93: Items [138, 168]
# Bin 94: Items [87, 188, 211]
# Bin 95: Items [37, 141]
# Bin 96: Items [63]
# Bin 97: Items [161, 167, 238]
# Bin 98: Items [210, 218]
#
# Falkenauer_u250_01.txt
# Optimal solution found!
# Bin 0: Items [204]
# Bin 1: Items []
# Bin 2: Items [54]
# Bin 3: Items [167, 244, 249]
# Bin 4: Items []
# Bin 5: Items []
# Bin 6: Items [206]
# Bin 7: Items [96]
# Bin 8: Items []
# Bin 9: Items [176]
# Bin 10: Items [59]
# Bin 11: Items [40]
# Bin 12: Items [183]
# Bin 13: Items [243]
# Bin 14: Items []
# Bin 15: Items [42]
# Bin 16: Items [191, 207]
# Bin 17: Items [72]
# Bin 18: Items [119]
# Bin 19: Items [109]
# Bin 20: Items [205]
# Bin 21: Items [121]
# Bin 22: Items [41, 124]
# Bin 23: Items [135]
# Bin 24: Items [0]
# Bin 25: Items [23]
# Bin 26: Items [128]
# Bin 27: Items [3, 82]
# Bin 28: Items [125]
# Bin 29: Items [36, 149]
# Bin 30: Items [134, 139]
# Bin 31: Items [126, 169]
# Bin 32: Items [133]
# Bin 33: Items [56]
# Bin 34: Items [73, 146]
# Bin 35: Items [177]
# Bin 36: Items [143, 208]
# Bin 37: Items [150]
# Bin 38: Items [5]
# Bin 39: Items [2]
# Bin 40: Items [44]
# Bin 41: Items []
# Bin 42: Items [117, 184]
# Bin 43: Items []
# Bin 44: Items []
# Bin 45: Items [57, 144]
# Bin 46: Items []
# Bin 47: Items [132]
# Bin 48: Items [120]
# Bin 49: Items [110, 145]
# Bin 50: Items [151]
# Bin 51: Items [127, 211]
# Bin 52: Items [210]
# Bin 53: Items []
# Bin 54: Items [45, 215]
# Bin 55: Items [78]
# Bin 56: Items [141]
# Bin 57: Items [46]
# Bin 58: Items [137, 147]
# Bin 59: Items [16, 140]
# Bin 60: Items [148, 152]
# Bin 61: Items [155, 212, 223]
# Bin 62: Items [81, 213]
# Bin 63: Items [97, 192]
# Bin 64: Items [79, 122]
# Bin 65: Items [99, 224]
# Bin 66: Items [94]
# Bin 67: Items [89, 178]
# Bin 68: Items [209]
# Bin 69: Items [55, 240]
# Bin 70: Items [12]
# Bin 71: Items [60, 68]
# Bin 72: Items [20, 222]
# Bin 73: Items [242]
# Bin 74: Items [138]
# Bin 75: Items [22, 86]
# Bin 76: Items [153]
# Bin 77: Items [75]
# Bin 78: Items [181, 214]
# Bin 79: Items [180]
# Bin 80: Items [74]
# Bin 81: Items [58, 131]
# Bin 82: Items [17, 154]
# Bin 83: Items [77, 226, 239]
# Bin 84: Items [136]
# Bin 85: Items [170]
# Bin 86: Items [130, 245]
# Bin 87: Items [80]
# Bin 88: Items [88, 142]
# Bin 89: Items [21]
# Bin 90: Items [123]
# Bin 91: Items [93]
# Bin 92: Items [95]
# Bin 93: Items [101, 179, 237]
# Bin 94: Items [39]
# Bin 95: Items [19, 247]
# Bin 96: Items [112, 168]
# Bin 97: Items [182, 231, 241]
# Bin 98: Items [185]
# Bin 99: Items [230]
#
# Falkenauer_u250_02.txt
# Optimal solution found!
# Bin 0: Items [121]
# Bin 1: Items [146, 159]
# Bin 2: Items [58]
# Bin 3: Items [57]
# Bin 4: Items [80]
# Bin 5: Items [47]
# Bin 6: Items [8]
# Bin 7: Items [132]
# Bin 8: Items [6]
# Bin 9: Items [117]
# Bin 10: Items [122]
# Bin 11: Items [167]
# Bin 12: Items []
# Bin 13: Items [131]
# Bin 14: Items [197]
# Bin 15: Items [96]
# Bin 16: Items [7]
# Bin 17: Items [69]
# Bin 18: Items [81]
# Bin 19: Items [107]
# Bin 20: Items []
# Bin 21: Items [68]
# Bin 22: Items [70]
# Bin 23: Items []
# Bin 24: Items [175]
# Bin 25: Items [156]
# Bin 26: Items []
# Bin 27: Items [180, 192]
# Bin 28: Items [187, 230]
# Bin 29: Items [207]
# Bin 30: Items [72, 169]
# Bin 31: Items [109, 235]
# Bin 32: Items []
# Bin 33: Items [79]
# Bin 34: Items [5]
# Bin 35: Items []
# Bin 36: Items []
# Bin 37: Items [32]
# Bin 38: Items [206, 224]
# Bin 39: Items [97]
# Bin 40: Items [189]
# Bin 41: Items [119]
# Bin 42: Items [157]
# Bin 43: Items [120]
# Bin 44: Items [50, 232]
# Bin 45: Items [71]
# Bin 46: Items [31]
# Bin 47: Items [84]
# Bin 48: Items [204, 223]
# Bin 49: Items [188, 190]
# Bin 50: Items [34]
# Bin 51: Items [191]
# Bin 52: Items [85, 179]
# Bin 53: Items [98]
# Bin 54: Items [114]
# Bin 55: Items [3]
# Bin 56: Items [33]
# Bin 57: Items [113]
# Bin 58: Items [134]
# Bin 59: Items [86]
# Bin 60: Items [172]
# Bin 61: Items [1, 222]
# Bin 62: Items [171, 195]
# Bin 63: Items [18, 174]
# Bin 64: Items [158, 173]
# Bin 65: Items [87, 205]
# Bin 66: Items [178, 194]
# Bin 67: Items [168, 231]
# Bin 68: Items [112, 210]
# Bin 69: Items [65, 219]
# Bin 70: Items [82]
# Bin 71: Items [218]
# Bin 72: Items [135]
# Bin 73: Items [100]
# Bin 74: Items [208, 234]
# Bin 75: Items [48, 226]
# Bin 76: Items [83]
# Bin 77: Items [91, 196]
# Bin 78: Items [94, 236]
# Bin 79: Items [108, 137]
# Bin 80: Items [90, 170]
# Bin 81: Items [45, 88]
# Bin 82: Items [111, 233]
# Bin 83: Items [138, 220]
# Bin 84: Items [93, 110]
# Bin 85: Items [116]
# Bin 86: Items [44]
# Bin 87: Items [209]
# Bin 88: Items [24]
# Bin 89: Items [89]
# Bin 90: Items [99, 148]
# Bin 91: Items [155, 193, 221]
# Bin 92: Items [211, 229]
# Bin 93: Items [4]
# Bin 94: Items [102, 147]
# Bin 95: Items [12, 185]
# Bin 96: Items [75, 92]
# Bin 97: Items [129, 130]
# Bin 98: Items [118, 199]
# Bin 99: Items [95, 106, 198]
# Bin 100: Items [22]
# Bin 101: Items [163, 201, 202]
#
# Falkenauer_u250_03.txt
# Optimal solution found!
# Bin 0: Items [43]
# Bin 1: Items []
# Bin 2: Items [72]
# Bin 3: Items []
# Bin 4: Items [68]
# Bin 5: Items [40]
# Bin 6: Items []
# Bin 7: Items []
# Bin 8: Items []
# Bin 9: Items [62]
# Bin 10: Items [30]
# Bin 11: Items [173]
# Bin 12: Items [66]
# Bin 13: Items [202, 205]
# Bin 14: Items []
# Bin 15: Items [151]
# Bin 16: Items [45]
# Bin 17: Items [71]
# Bin 18: Items [11]
# Bin 19: Items [54]
# Bin 20: Items [61]
# Bin 21: Items [74]
# Bin 22: Items [47]
# Bin 23: Items [27]
# Bin 24: Items [14]
# Bin 25: Items [132]
# Bin 26: Items []
# Bin 27: Items [152]
# Bin 28: Items [69]
# Bin 29: Items [97]
# Bin 30: Items [131]
# Bin 31: Items [65]
# Bin 32: Items [96]
# Bin 33: Items []
# Bin 34: Items []
# Bin 35: Items [187]
# Bin 36: Items [13]
# Bin 37: Items [175, 211, 246]
# Bin 38: Items []
# Bin 39: Items [63]
# Bin 40: Items [42]
# Bin 41: Items [204]
# Bin 42: Items [128]
# Bin 43: Items [203, 212]
# Bin 44: Items [46]
# Bin 45: Items [10, 220]
# Bin 46: Items [56, 215]
# Bin 47: Items [32]
# Bin 48: Items [174]
# Bin 49: Items [166]
# Bin 50: Items [55, 129]
# Bin 51: Items [58]
# Bin 52: Items [90, 217]
# Bin 53: Items [33]
# Bin 54: Items [127, 213, 244]
# Bin 55: Items [130, 196]
# Bin 56: Items [162, 222]
# Bin 57: Items [59]
# Bin 58: Items [218]
# Bin 59: Items [48]
# Bin 60: Items [60]
# Bin 61: Items [214, 216, 231, 234]
# Bin 62: Items [39, 76]
# Bin 63: Items [19, 163]
# Bin 64: Items [164]
# Bin 65: Items [78]
# Bin 66: Items [67, 167]
# Bin 67: Items [82]
# Bin 68: Items [83, 176]
# Bin 69: Items [89]
# Bin 70: Items [57]
# Bin 71: Items [53, 188]
# Bin 72: Items [22]
# Bin 73: Items [75, 186]
# Bin 74: Items [104]
# Bin 75: Items [81]
# Bin 76: Items [73, 229]
# Bin 77: Items [31]
# Bin 78: Items [20, 165]
# Bin 79: Items [106, 194]
# Bin 80: Items [17, 185]
# Bin 81: Items [23, 192]
# Bin 82: Items [155]
# Bin 83: Items [77, 126]
# Bin 84: Items [80, 105]
# Bin 85: Items [108, 156]
# Bin 86: Items [84, 133]
# Bin 87: Items [111, 191]
# Bin 88: Items [107, 184]
# Bin 89: Items [195]
# Bin 90: Items [79]
# Bin 91: Items [64, 219]
# Bin 92: Items [85, 117, 170]
# Bin 93: Items [123, 172, 230]
# Bin 94: Items [124, 183, 235]
# Bin 95: Items [118, 233]
# Bin 96: Items [221, 232]
# Bin 97: Items [125, 178, 197]
# Bin 98: Items [114, 181]
# Bin 99: Items [193, 198, 200, 237]
#
# Falkenauer_u250_04.txt
# Optimal solution found!
# Bin 0: Items [226]
# Bin 1: Items [123]
# Bin 2: Items []
# Bin 3: Items [45, 208]
# Bin 4: Items [228]
# Bin 5: Items []
# Bin 6: Items []
# Bin 7: Items [47]
# Bin 8: Items [59]
# Bin 9: Items [143]
# Bin 10: Items [65]
# Bin 11: Items []
# Bin 12: Items [9]
# Bin 13: Items [3]
# Bin 14: Items [8]
# Bin 15: Items [167]
# Bin 16: Items [44]
# Bin 17: Items [6]
# Bin 18: Items [85]
# Bin 19: Items [122]
# Bin 20: Items [96]
# Bin 21: Items [10]
# Bin 22: Items []
# Bin 23: Items [91]
# Bin 24: Items [15, 234]
# Bin 25: Items [160]
# Bin 26: Items [68]
# Bin 27: Items []
# Bin 28: Items [112]
# Bin 29: Items [46]
# Bin 30: Items [90, 144]
# Bin 31: Items [165]
# Bin 32: Items [158]
# Bin 33: Items [86, 186]
# Bin 34: Items []
# Bin 35: Items [49]
# Bin 36: Items [183]
# Bin 37: Items [113]
# Bin 38: Items [64, 222]
# Bin 39: Items [52]
# Bin 40: Items [100]
# Bin 41: Items []
# Bin 42: Items [7]
# Bin 43: Items [159]
# Bin 44: Items [35]
# Bin 45: Items [2]
# Bin 46: Items [207]
# Bin 47: Items [99]
# Bin 48: Items [48]
# Bin 49: Items [235]
# Bin 50: Items [161, 179]
# Bin 51: Items [180]
# Bin 52: Items [76]
# Bin 53: Items [98, 223]
# Bin 54: Items [51]
# Bin 55: Items [126]
# Bin 56: Items [95]
# Bin 57: Items [14, 227]
# Bin 58: Items [93, 220]
# Bin 59: Items [115]
# Bin 60: Items [5]
# Bin 61: Items [62, 221]
# Bin 62: Items [219]
# Bin 63: Items [92]
# Bin 64: Items [43, 232]
# Bin 65: Items [199]
# Bin 66: Items [200]
# Bin 67: Items [97, 238]
# Bin 68: Items [182, 211]
# Bin 69: Items [53, 205]
# Bin 70: Items [94, 168, 218]
# Bin 71: Items [50]
# Bin 72: Items [209, 212, 230]
# Bin 73: Items [229]
# Bin 74: Items [162]
# Bin 75: Items [63]
# Bin 76: Items [181, 206]
# Bin 77: Items [67, 214]
# Bin 78: Items [71]
# Bin 79: Items [56]
# Bin 80: Items [124, 170]
# Bin 81: Items [70, 166]
# Bin 82: Items [13, 184]
# Bin 83: Items [164, 210]
# Bin 84: Items [114, 233]
# Bin 85: Items [89]
# Bin 86: Items [147, 204, 217]
# Bin 87: Items [26, 239]
# Bin 88: Items [87]
# Bin 89: Items [145]
# Bin 90: Items [127, 245]
# Bin 91: Items [75, 142, 236]
# Bin 92: Items [138, 203]
# Bin 93: Items [107, 185, 224]
# Bin 94: Items [163, 213]
# Bin 95: Items [32, 121, 225]
# Bin 96: Items []
# Bin 97: Items [12, 74]
# Bin 98: Items [202, 249]
# Bin 99: Items [116, 125, 237]
# Bin 100: Items [231, 246, 247, 248]
#
# Falkenauer_u250_05.txt
# Optimal solution found!
# Bin 0: Items [180]
# Bin 1: Items []
# Bin 2: Items [89]
# Bin 3: Items []
# Bin 4: Items [52]
# Bin 5: Items [58]
# Bin 6: Items [56]
# Bin 7: Items [90]
# Bin 8: Items [20, 213]
# Bin 9: Items [92]
# Bin 10: Items [24]
# Bin 11: Items [83]
# Bin 12: Items [178, 214]
# Bin 13: Items [53]
# Bin 14: Items [22]
# Bin 15: Items [118]
# Bin 16: Items [36]
# Bin 17: Items [124, 186]
# Bin 18: Items [21]
# Bin 19: Items [84]
# Bin 20: Items [23]
# Bin 21: Items [132]
# Bin 22: Items [121]
# Bin 23: Items [45]
# Bin 24: Items [57]
# Bin 25: Items [50]
# Bin 26: Items [100]
# Bin 27: Items [179]
# Bin 28: Items [188]
# Bin 29: Items [54]
# Bin 30: Items [169]
# Bin 31: Items [55, 159]
# Bin 32: Items [61]
# Bin 33: Items [39]
# Bin 34: Items [99]
# Bin 35: Items [143]
# Bin 36: Items [211]
# Bin 37: Items [238]
# Bin 38: Items [107]
# Bin 39: Items [87, 88]
# Bin 40: Items [123, 181]
# Bin 41: Items [98, 122]
# Bin 42: Items [60]
# Bin 43: Items [91]
# Bin 44: Items [171]
# Bin 45: Items [166]
# Bin 46: Items [18]
# Bin 47: Items [106, 236]
# Bin 48: Items [38, 237]
# Bin 49: Items [165]
# Bin 50: Items [93, 187, 248]
# Bin 51: Items [96]
# Bin 52: Items [35, 244]
# Bin 53: Items [81]
# Bin 54: Items [94, 212]
# Bin 55: Items [112, 168]
# Bin 56: Items [108]
# Bin 57: Items [246, 247]
# Bin 58: Items [131]
# Bin 59: Items [95]
# Bin 60: Items [79, 133]
# Bin 61: Items [32, 86]
# Bin 62: Items [85, 164]
# Bin 63: Items [42]
# Bin 64: Items [43, 144]
# Bin 65: Items [128, 161]
# Bin 66: Items [170, 215]
# Bin 67: Items [185, 217]
# Bin 68: Items [120]
# Bin 69: Items [184, 210]
# Bin 70: Items [0, 139]
# Bin 71: Items [44, 109]
# Bin 72: Items [11, 177, 221]
# Bin 73: Items [17, 218]
# Bin 74: Items [14, 183]
# Bin 75: Items [126, 201]
# Bin 76: Items [162, 182]
# Bin 77: Items [111]
# Bin 78: Items [102, 142]
# Bin 79: Items [13]
# Bin 80: Items [9]
# Bin 81: Items [8, 167]
# Bin 82: Items [10, 117]
# Bin 83: Items [15, 193]
# Bin 84: Items [12, 189]
# Bin 85: Items [110, 136]
# Bin 86: Items [114, 125]
# Bin 87: Items [103, 196]
# Bin 88: Items [97]
# Bin 89: Items [158]
# Bin 90: Items [119, 200]
# Bin 91: Items [16, 192, 245]
# Bin 92: Items [51, 160, 249]
# Bin 93: Items [129]
# Bin 94: Items [105, 113, 194]
# Bin 95: Items [141, 199]
# Bin 96: Items [163, 190]
# Bin 97: Items [115, 140, 220]
# Bin 98: Items [116, 191]
# Bin 99: Items [145, 203, 205, 216, 239, 243]
# Bin 100: Items [155, 228, 230]
#
# Falkenauer_u250_06.txt
# Optimal solution found!
# Bin 0: Items [167, 172, 230]
# Bin 1: Items []
# Bin 2: Items []
# Bin 3: Items []
# Bin 4: Items [63, 218]
# Bin 5: Items [99]
# Bin 6: Items [25]
# Bin 7: Items [166]
# Bin 8: Items []
# Bin 9: Items [132]
# Bin 10: Items []
# Bin 11: Items [27]
# Bin 12: Items []
# Bin 13: Items [201]
# Bin 14: Items [72]
# Bin 15: Items [36]
# Bin 16: Items [117]
# Bin 17: Items []
# Bin 18: Items [8]
# Bin 19: Items []
# Bin 20: Items [11]
# Bin 21: Items [41]
# Bin 22: Items [20]
# Bin 23: Items [113]
# Bin 24: Items [203, 236]
# Bin 25: Items [134]
# Bin 26: Items []
# Bin 27: Items [139, 181]
# Bin 28: Items [136, 219]
# Bin 29: Items [133]
# Bin 30: Items [106, 146]
# Bin 31: Items [119, 138]
# Bin 32: Items []
# Bin 33: Items [71]
# Bin 34: Items [24, 164]
# Bin 35: Items [42]
# Bin 36: Items [135, 202]
# Bin 37: Items [73]
# Bin 38: Items [64, 234]
# Bin 39: Items [183]
# Bin 40: Items [65]
# Bin 41: Items [169, 205, 206]
# Bin 42: Items [9]
# Bin 43: Items [179]
# Bin 44: Items [35, 221, 222]
# Bin 45: Items [154]
# Bin 46: Items [184, 190, 204]
# Bin 47: Items [186, 245]
# Bin 48: Items [43, 168]
# Bin 49: Items [39, 227]
# Bin 50: Items [235]
# Bin 51: Items [1]
# Bin 52: Items [28]
# Bin 53: Items [131]
# Bin 54: Items [105, 140]
# Bin 55: Items [7, 182]
# Bin 56: Items [173]
# Bin 57: Items [180, 231]
# Bin 58: Items [216]
# Bin 59: Items [52, 165]
# Bin 60: Items [215, 233]
# Bin 61: Items [220]
# Bin 62: Items []
# Bin 63: Items [40]
# Bin 64: Items []
# Bin 65: Items [152, 232]
# Bin 66: Items [101]
# Bin 67: Items [53, 137]
# Bin 68: Items [15]
# Bin 69: Items [18]
# Bin 70: Items [121, 171, 228]
# Bin 71: Items [116]
# Bin 72: Items [16]
# Bin 73: Items [5, 130]
# Bin 74: Items []
# Bin 75: Items [114]
# Bin 76: Items [150, 187, 199]
# Bin 77: Items [10, 185]
# Bin 78: Items [100, 177]
# Bin 79: Items [29, 87]
# Bin 80: Items [178]
# Bin 81: Items [198]
# Bin 82: Items [104]
# Bin 83: Items [153]
# Bin 84: Items [144]
# Bin 85: Items [86]
# Bin 86: Items [23, 229]
# Bin 87: Items [38]
# Bin 88: Items [170, 217]
# Bin 89: Items [226]
# Bin 90: Items [21]
# Bin 91: Items [188, 211]
# Bin 92: Items [102]
# Bin 93: Items [55]
# Bin 94: Items [22, 162]
# Bin 95: Items [129, 141]
# Bin 96: Items [176, 193, 225]
# Bin 97: Items [75, 147]
# Bin 98: Items [115, 145]
# Bin 99: Items [125]
# Bin 100: Items [26]
# Bin 101: Items [157, 174, 175, 247]
#
# Falkenauer_u250_07.txt
# Optimal solution found!
# Bin 0: Items []
# Bin 1: Items [101]
# Bin 2: Items []
# Bin 3: Items [21]
# Bin 4: Items [50]
# Bin 5: Items [80]
# Bin 6: Items []
# Bin 7: Items [35]
# Bin 8: Items [18]
# Bin 9: Items []
# Bin 10: Items [141]
# Bin 11: Items []
# Bin 12: Items [244]
# Bin 13: Items [23, 233]
# Bin 14: Items []
# Bin 15: Items [68]
# Bin 16: Items [136, 211]
# Bin 17: Items [67]
# Bin 18: Items [22]
# Bin 19: Items []
# Bin 20: Items [79, 214]
# Bin 21: Items [53]
# Bin 22: Items [154]
# Bin 23: Items [33]
# Bin 24: Items []
# Bin 25: Items [153]
# Bin 26: Items [70]
# Bin 27: Items [96]
# Bin 28: Items [49, 133]
# Bin 29: Items [107]
# Bin 30: Items [66]
# Bin 31: Items [143]
# Bin 32: Items [110]
# Bin 33: Items [152]
# Bin 34: Items [142, 212]
# Bin 35: Items [189]
# Bin 36: Items [188]
# Bin 37: Items [52, 157]
# Bin 38: Items [89, 156]
# Bin 39: Items [135]
# Bin 40: Items [191, 192]
# Bin 41: Items [181, 245]
# Bin 42: Items [57]
# Bin 43: Items [71, 102]
# Bin 44: Items [232]
# Bin 45: Items [54, 183]
# Bin 46: Items [111]
# Bin 47: Items [213]
# Bin 48: Items []
# Bin 49: Items [124]
# Bin 50: Items [109, 170]
# Bin 51: Items [15]
# Bin 52: Items [26]
# Bin 53: Items []
# Bin 54: Items [162]
# Bin 55: Items [134]
# Bin 56: Items [14]
# Bin 57: Items [90]
# Bin 58: Items [64]
# Bin 59: Items [144, 171]
# Bin 60: Items [179, 205]
# Bin 61: Items [163, 190]
# Bin 62: Items [206]
# Bin 63: Items [69]
# Bin 64: Items [65]
# Bin 65: Items [88, 246]
# Bin 66: Items [106, 247]
# Bin 67: Items [60]
# Bin 68: Items [91]
# Bin 69: Items [61, 158]
# Bin 70: Items [148]
# Bin 71: Items [56]
# Bin 72: Items [138, 149]
# Bin 73: Items [51]
# Bin 74: Items [87, 151]
# Bin 75: Items [160, 172, 208]
# Bin 76: Items [112, 182]
# Bin 77: Items [47, 207]
# Bin 78: Items [147, 161]
# Bin 79: Items [199]
# Bin 80: Items [86, 187]
# Bin 81: Items [20]
# Bin 82: Items [137, 224]
# Bin 83: Items [36]
# Bin 84: Items [40]
# Bin 85: Items [63, 178]
# Bin 86: Items [198, 217]
# Bin 87: Items [146, 248]
# Bin 88: Items [121, 209, 215]
# Bin 89: Items [41]
# Bin 90: Items [46, 249]
# Bin 91: Items [174, 204, 227]
# Bin 92: Items [155, 210]
# Bin 93: Items [34, 145]
# Bin 94: Items [58, 75, 219]
# Bin 95: Items [59]
# Bin 96: Items [62, 94, 221]
# Bin 97: Items [173, 175, 177, 186]
# Bin 98: Items [150, 159]
# Bin 99: Items [44, 225]
# Bin 100: Items [25, 176, 193]
# Bin 101: Items [108]
# Bin 102: Items [216, 218, 220, 222, 226]
#
# Falkenauer_u250_08.txt
# No optimal solution found.
#
# Falkenauer_u250_09.txt
# Optimal solution found!
# Bin 0: Items [10]
# Bin 1: Items [238]
# Bin 2: Items [25]
# Bin 3: Items [134]
# Bin 4: Items []
# Bin 5: Items [85]
# Bin 6: Items [66]
# Bin 7: Items []
# Bin 8: Items [17, 181]
# Bin 9: Items [112, 204]
# Bin 10: Items [73, 203]
# Bin 11: Items [142]
# Bin 12: Items [122]
# Bin 13: Items [67]
# Bin 14: Items [51]
# Bin 15: Items []
# Bin 16: Items [113]
# Bin 17: Items [18]
# Bin 18: Items []
# Bin 19: Items [141, 215]
# Bin 20: Items [47]
# Bin 21: Items [68, 69]
# Bin 22: Items []
# Bin 23: Items []
# Bin 24: Items [92]
# Bin 25: Items [156, 239]
# Bin 26: Items [81]
# Bin 27: Items [74]
# Bin 28: Items [157]
# Bin 29: Items [89, 136]
# Bin 30: Items [35]
# Bin 31: Items [190, 192, 205]
# Bin 32: Items []
# Bin 33: Items []
# Bin 34: Items [105]
# Bin 35: Items [162]
# Bin 36: Items [75]
# Bin 37: Items [86]
# Bin 38: Items [240]
# Bin 39: Items [124]
# Bin 40: Items [164, 189]
# Bin 41: Items []
# Bin 42: Items []
# Bin 43: Items [188]
# Bin 44: Items [70]
# Bin 45: Items []
# Bin 46: Items [50]
# Bin 47: Items [52]
# Bin 48: Items [34]
# Bin 49: Items [103]
# Bin 50: Items [125]
# Bin 51: Items [143]
# Bin 52: Items [180]
# Bin 53: Items [160]
# Bin 54: Items [71]
# Bin 55: Items [159, 176]
# Bin 56: Items []
# Bin 57: Items [108, 126]
# Bin 58: Items [49]
# Bin 59: Items [153, 163]
# Bin 60: Items [93, 114]
# Bin 61: Items []
# Bin 62: Items [155, 179]
# Bin 63: Items [29, 167, 217]
# Bin 64: Items [82]
# Bin 65: Items [128, 144]
# Bin 66: Items [26]
# Bin 67: Items [19, 121]
# Bin 68: Items [87]
# Bin 69: Items [152, 228]
# Bin 70: Items [174, 230]
# Bin 71: Items [101]
# Bin 72: Items [201]
# Bin 73: Items [32]
# Bin 74: Items [31, 231]
# Bin 75: Items [90]
# Bin 76: Items [94]
# Bin 77: Items [191]
# Bin 78: Items [53, 178, 227]
# Bin 79: Items [40, 161]
# Bin 80: Items [111]
# Bin 81: Items [175, 187]
# Bin 82: Items [46, 166]
# Bin 83: Items [123, 177]
# Bin 84: Items [135]
# Bin 85: Items [72]
# Bin 86: Items [2]
# Bin 87: Items [218]
# Bin 88: Items [183, 193]
# Bin 89: Items [84, 106]
# Bin 90: Items [104, 127]
# Bin 91: Items [88, 107]
# Bin 92: Items [5]
# Bin 93: Items [54, 195, 229]
# Bin 94: Items [211]
# Bin 95: Items [83]
# Bin 96: Items [48, 216, 226]
# Bin 97: Items [117, 207, 208]
# Bin 98: Items [38, 200]
# Bin 99: Items [241, 242]
# Bin 100: Items [102, 158]
#
# Falkenauer_u250_10.txt
# Optimal solution found!
# Bin 0: Items [14]
# Bin 1: Items [220]
# Bin 2: Items [85]
# Bin 3: Items [231]
# Bin 4: Items [25]
# Bin 5: Items [12]
# Bin 6: Items [106]
# Bin 7: Items [84]
# Bin 8: Items [50]
# Bin 9: Items []
# Bin 10: Items [240]
# Bin 11: Items [77]
# Bin 12: Items [76]
# Bin 13: Items []
# Bin 14: Items [15]
# Bin 15: Items [93]
# Bin 16: Items [38]
# Bin 17: Items []
# Bin 18: Items [229]
# Bin 19: Items [117]
# Bin 20: Items [121]
# Bin 21: Items []
# Bin 22: Items [92]
# Bin 23: Items [109]
# Bin 24: Items [119]
# Bin 25: Items [171]
# Bin 26: Items [110]
# Bin 27: Items [246]
# Bin 28: Items [129, 230]
# Bin 29: Items []
# Bin 30: Items []
# Bin 31: Items [177]
# Bin 32: Items [13]
# Bin 33: Items [16]
# Bin 34: Items [100, 181]
# Bin 35: Items [162]
# Bin 36: Items []
# Bin 37: Items [65]
# Bin 38: Items [94]
# Bin 39: Items []
# Bin 40: Items [120, 208]
# Bin 41: Items [39]
# Bin 42: Items [116]
# Bin 43: Items [11]
# Bin 44: Items [232]
# Bin 45: Items [179, 247]
# Bin 46: Items []
# Bin 47: Items [223]
# Bin 48: Items [222]
# Bin 49: Items [111, 237]
# Bin 50: Items [99]
# Bin 51: Items [160]
# Bin 52: Items [204]
# Bin 53: Items [172]
# Bin 54: Items [192]
# Bin 55: Items [54]
# Bin 56: Items [49]
# Bin 57: Items [51]
# Bin 58: Items [122]
# Bin 59: Items [27]
# Bin 60: Items [207, 213, 249]
# Bin 61: Items [83, 224]
# Bin 62: Items [55]
# Bin 63: Items [125, 206]
# Bin 64: Items [101, 115]
# Bin 65: Items [118, 205]
# Bin 66: Items [86]
# Bin 67: Items [130, 248]
# Bin 68: Items [214]
# Bin 69: Items [127, 165]
# Bin 70: Items [56]
# Bin 71: Items [46]
# Bin 72: Items [30]
# Bin 73: Items [48, 166]
# Bin 74: Items [31, 141]
# Bin 75: Items [124]
# Bin 76: Items [140]
# Bin 77: Items [128, 216]
# Bin 78: Items [138]
# Bin 79: Items [105, 238]
# Bin 80: Items [180]
# Bin 81: Items [47, 211]
# Bin 82: Items [103, 164]
# Bin 83: Items [102, 236]
# Bin 84: Items [104, 209]
# Bin 85: Items [114, 221]
# Bin 86: Items [108]
# Bin 87: Items [137]
# Bin 88: Items [168, 178]
# Bin 89: Items [139, 142]
# Bin 90: Items [97, 169]
# Bin 91: Items [41, 71]
# Bin 92: Items [113, 210, 225]
# Bin 93: Items [112, 194]
# Bin 94: Items [2, 151]
# Bin 95: Items [53, 163]
# Bin 96: Items [81, 126, 170]
# Bin 97: Items [107, 186]
# Bin 98: Items [67, 123]
# Bin 99: Items [155, 184]
# Bin 100: Items [1]
# Bin 101: Items [3]
# Bin 102: Items [28, 185, 234]
# Bin 103: Items [187, 193, 212, 239]
# Bin 104: Items [182, 183, 201]
#
# Falkenauer_u250_11.txt
# Optimal solution found!
# Bin 0: Items [78]
# Bin 1: Items []
# Bin 2: Items [79]
# Bin 3: Items []
# Bin 4: Items [242]
# Bin 5: Items [6]
# Bin 6: Items []
# Bin 7: Items [54]
# Bin 8: Items []
# Bin 9: Items []
# Bin 10: Items [66, 155]
# Bin 11: Items [15, 243]
# Bin 12: Items [193]
# Bin 13: Items [25, 96]
# Bin 14: Items []
# Bin 15: Items [14]
# Bin 16: Items [147, 160]
# Bin 17: Items [90, 140]
# Bin 18: Items [34]
# Bin 19: Items [146]
# Bin 20: Items [94, 141]
# Bin 21: Items [206]
# Bin 22: Items [8]
# Bin 23: Items [102, 111]
# Bin 24: Items [131]
# Bin 25: Items []
# Bin 26: Items [104]
# Bin 27: Items [148]
# Bin 28: Items [89]
# Bin 29: Items [26]
# Bin 30: Items []
# Bin 31: Items []
# Bin 32: Items [196]
# Bin 33: Items [77, 106, 197]
# Bin 34: Items [113]
# Bin 35: Items [50]
# Bin 36: Items [95]
# Bin 37: Items [80]
# Bin 38: Items [51, 132]
# Bin 39: Items [128]
# Bin 40: Items [65]
# Bin 41: Items [110, 219]
# Bin 42: Items [192]
# Bin 43: Items [17, 189]
# Bin 44: Items [190]
# Bin 45: Items []
# Bin 46: Items [97, 226]
# Bin 47: Items [81, 230]
# Bin 48: Items [149, 195]
# Bin 49: Items [227]
# Bin 50: Items []
# Bin 51: Items [83]
# Bin 52: Items [92]
# Bin 53: Items [16, 130]
# Bin 54: Items [107, 108]
# Bin 55: Items [109]
# Bin 56: Items [100, 118]
# Bin 57: Items [82]
# Bin 58: Items [159, 173]
# Bin 59: Items [115]
# Bin 60: Items [139, 217]
# Bin 61: Items [125, 168]
# Bin 62: Items [52]
# Bin 63: Items [93, 245]
# Bin 64: Items [5]
# Bin 65: Items []
# Bin 66: Items [53]
# Bin 67: Items [112, 145]
# Bin 68: Items [91, 228]
# Bin 69: Items [162, 232]
# Bin 70: Items [187]
# Bin 71: Items [105, 180]
# Bin 72: Items [218]
# Bin 73: Items []
# Bin 74: Items [142]
# Bin 75: Items [194]
# Bin 76: Items [114]
# Bin 77: Items [161]
# Bin 78: Items [103]
# Bin 79: Items [157]
# Bin 80: Items [73, 198]
# Bin 81: Items [156, 158]
# Bin 82: Items [116, 152]
# Bin 83: Items [129, 181]
# Bin 84: Items [88, 184]
# Bin 85: Items [72, 153]
# Bin 86: Items [150]
# Bin 87: Items [120, 231]
# Bin 88: Items [123, 233]
# Bin 89: Items [208, 225]
# Bin 90: Items []
# Bin 91: Items [42]
# Bin 92: Items [117, 121, 172]
# Bin 93: Items [143]
# Bin 94: Items [124, 211]
# Bin 95: Items [144, 229, 241, 244]
# Bin 96: Items [55, 133]
# Bin 97: Items [185, 209]
# Bin 98: Items [176]
# Bin 99: Items [164, 240]
# Bin 100: Items [199, 207]
#
# Falkenauer_u250_12.txt
# Optimal solution found!
# Bin 0: Items [148, 249]
# Bin 1: Items []
# Bin 2: Items []
# Bin 3: Items []
# Bin 4: Items [91]
# Bin 5: Items []
# Bin 6: Items [39]
# Bin 7: Items [172, 225]
# Bin 8: Items []
# Bin 9: Items []
# Bin 10: Items [43]
# Bin 11: Items [89]
# Bin 12: Items [211]
# Bin 13: Items [78]
# Bin 14: Items [50]
# Bin 15: Items [77]
# Bin 16: Items []
# Bin 17: Items [90]
# Bin 18: Items [58]
# Bin 19: Items [79, 202]
# Bin 20: Items [132]
# Bin 21: Items []
# Bin 22: Items [208]
# Bin 23: Items [116]
# Bin 24: Items [52]
# Bin 25: Items [231]
# Bin 26: Items [51]
# Bin 27: Items [119]
# Bin 28: Items []
# Bin 29: Items [129]
# Bin 30: Items [59]
# Bin 31: Items [118, 210]
# Bin 32: Items [131]
# Bin 33: Items [84]
# Bin 34: Items [114]
# Bin 35: Items [243]
# Bin 36: Items []
# Bin 37: Items [158, 201, 242]
# Bin 38: Items [83]
# Bin 39: Items [45, 200]
# Bin 40: Items [40]
# Bin 41: Items [134]
# Bin 42: Items [75]
# Bin 43: Items []
# Bin 44: Items [23]
# Bin 45: Items [86]
# Bin 46: Items []
# Bin 47: Items [130]
# Bin 48: Items [209]
# Bin 49: Items [149]
# Bin 50: Items [57]
# Bin 51: Items [173]
# Bin 52: Items [100]
# Bin 53: Items [80]
# Bin 54: Items [115, 207]
# Bin 55: Items [46, 81]
# Bin 56: Items [56, 224]
# Bin 57: Items []
# Bin 58: Items [88, 232]
# Bin 59: Items [159]
# Bin 60: Items [93, 205]
# Bin 61: Items [72]
# Bin 62: Items [104, 206]
# Bin 63: Items [128]
# Bin 64: Items [94, 219]
# Bin 65: Items [117]
# Bin 66: Items [203]
# Bin 67: Items [70]
# Bin 68: Items [5]
# Bin 69: Items [124]
# Bin 70: Items [61, 222]
# Bin 71: Items [97]
# Bin 72: Items [135]
# Bin 73: Items [102, 218]
# Bin 74: Items [71, 85]
# Bin 75: Items [155]
# Bin 76: Items [54, 150]
# Bin 77: Items [44, 163]
# Bin 78: Items [154, 185, 221]
# Bin 79: Items [53, 160]
# Bin 80: Items [95, 161]
# Bin 81: Items [64]
# Bin 82: Items [167]
# Bin 83: Items [180, 244, 248]
# Bin 84: Items [162, 204]
# Bin 85: Items [55, 165]
# Bin 86: Items [212, 223]
# Bin 87: Items [34, 184]
# Bin 88: Items [164]
# Bin 89: Items [73, 152]
# Bin 90: Items [63, 109]
# Bin 91: Items [121, 166]
# Bin 92: Items [156, 220]
# Bin 93: Items [48, 168]
# Bin 94: Items [139, 153]
# Bin 95: Items [151, 170, 215]
# Bin 96: Items [67, 92]
# Bin 97: Items []
# Bin 98: Items [103, 125, 183]
# Bin 99: Items [62, 177]
# Bin 100: Items [82]
# Bin 101: Items [157, 175, 229]
# Bin 102: Items [174, 178]
# Bin 103: Items [140, 193, 233, 239]
# Bin 104: Items [144, 176, 192]
#
# Falkenauer_u250_13.txt
# Optimal solution found!
# Bin 0: Items [33]
# Bin 1: Items [54]
# Bin 2: Items [224, 231]
# Bin 3: Items [119, 226]
# Bin 4: Items [236, 245]
# Bin 5: Items [47]
# Bin 6: Items []
# Bin 7: Items [0, 223]
# Bin 8: Items [23]
# Bin 9: Items []
# Bin 10: Items [120]
# Bin 11: Items []
# Bin 12: Items [21]
# Bin 13: Items [155]
# Bin 14: Items []
# Bin 15: Items [137]
# Bin 16: Items [63]
# Bin 17: Items [13]
# Bin 18: Items [46, 136]
# Bin 19: Items [66]
# Bin 20: Items [48, 230]
# Bin 21: Items [239]
# Bin 22: Items [145]
# Bin 23: Items [67]
# Bin 24: Items [55]
# Bin 25: Items []
# Bin 26: Items []
# Bin 27: Items [182]
# Bin 28: Items [117]
# Bin 29: Items [206]
# Bin 30: Items [24]
# Bin 31: Items [156]
# Bin 32: Items [241]
# Bin 33: Items []
# Bin 34: Items [2, 234]
# Bin 35: Items [1]
# Bin 36: Items [208, 244]
# Bin 37: Items []
# Bin 38: Items []
# Bin 39: Items [31]
# Bin 40: Items [45]
# Bin 41: Items [14, 154]
# Bin 42: Items [11]
# Bin 43: Items [228]
# Bin 44: Items [9]
# Bin 45: Items [139]
# Bin 46: Items [39, 238]
# Bin 47: Items [213, 214]
# Bin 48: Items [85]
# Bin 49: Items [232]
# Bin 50: Items [82, 235, 237]
# Bin 51: Items [86]
# Bin 52: Items [3, 233]
# Bin 53: Items [183]
# Bin 54: Items [83]
# Bin 55: Items [89]
# Bin 56: Items [26]
# Bin 57: Items [157]
# Bin 58: Items [138]
# Bin 59: Items [140]
# Bin 60: Items []
# Bin 61: Items [96]
# Bin 62: Items [28]
# Bin 63: Items [98, 165]
# Bin 64: Items [158]
# Bin 65: Items [51, 97]
# Bin 66: Items [10, 240]
# Bin 67: Items [88]
# Bin 68: Items [207]
# Bin 69: Items [43]
# Bin 70: Items [49, 220]
# Bin 71: Items [153, 225]
# Bin 72: Items [81]
# Bin 73: Items [118, 166]
# Bin 74: Items [25, 248]
# Bin 75: Items [52]
# Bin 76: Items [5, 152]
# Bin 77: Items [35, 180]
# Bin 78: Items [84]
# Bin 79: Items [209, 221, 243]
# Bin 80: Items [164, 178, 219]
# Bin 81: Items [53, 246]
# Bin 82: Items [34, 215]
# Bin 83: Items [128, 249]
# Bin 84: Items [8, 41]
# Bin 85: Items [129, 163]
# Bin 86: Items []
# Bin 87: Items [87]
# Bin 88: Items [112, 170, 211]
# Bin 89: Items [115, 161, 184]
# Bin 90: Items [126]
# Bin 91: Items [127]
# Bin 92: Items [38]
# Bin 93: Items [64, 210, 229]
# Bin 94: Items [91]
# Bin 95: Items [6]
# Bin 96: Items [125]
# Bin 97: Items [141, 227, 247]
# Bin 98: Items [147, 168, 218, 222]
# Bin 99: Items [179, 185]
# Bin 100: Items [94, 242]
# Bin 101: Items [186]
#
# Falkenauer_u250_14.txt
# Optimal solution found!
# Bin 0: Items []
# Bin 1: Items [95]
# Bin 2: Items []
# Bin 3: Items [30]
# Bin 4: Items [97]
# Bin 5: Items []
# Bin 6: Items [166]
# Bin 7: Items [143]
# Bin 8: Items [165]
# Bin 9: Items [186]
# Bin 10: Items []
# Bin 11: Items [135]
# Bin 12: Items []
# Bin 13: Items [106]
# Bin 14: Items [28]
# Bin 15: Items [46, 219]
# Bin 16: Items [188]
# Bin 17: Items [79]
# Bin 18: Items [111]
# Bin 19: Items [136]
# Bin 20: Items [56]
# Bin 21: Items [43]
# Bin 22: Items [96, 206]
# Bin 23: Items [149]
# Bin 24: Items [121]
# Bin 25: Items [158]
# Bin 26: Items [207, 229]
# Bin 27: Items [202, 203]
# Bin 28: Items [58]
# Bin 29: Items [32]
# Bin 30: Items [138]
# Bin 31: Items [40]
# Bin 32: Items [100]
# Bin 33: Items [123, 156]
# Bin 34: Items [117]
# Bin 35: Items [181]
# Bin 36: Items [98]
# Bin 37: Items [59, 213]
# Bin 38: Items [44]
# Bin 39: Items [45]
# Bin 40: Items []
# Bin 41: Items [78]
# Bin 42: Items [157, 191]
# Bin 43: Items [112, 208]
# Bin 44: Items [0]
# Bin 45: Items [99, 129, 214]
# Bin 46: Items [42]
# Bin 47: Items [2, 212]
# Bin 48: Items [118]
# Bin 49: Items [34, 210]
# Bin 50: Items [41]
# Bin 51: Items [205]
# Bin 52: Items [77, 211]
# Bin 53: Items [120, 142]
# Bin 54: Items [6]
# Bin 55: Items [4, 48]
# Bin 56: Items [185, 204]
# Bin 57: Items [141, 187]
# Bin 58: Items [119, 209]
# Bin 59: Items [105]
# Bin 60: Items [114, 180]
# Bin 61: Items [69, 201]
# Bin 62: Items [67, 109]
# Bin 63: Items [104, 220]
# Bin 64: Items [5]
# Bin 65: Items [70, 247]
# Bin 66: Items [93]
# Bin 67: Items [107, 218]
# Bin 68: Items [139]
# Bin 69: Items [169, 182]
# Bin 70: Items [168]
# Bin 71: Items [101, 184]
# Bin 72: Items [21, 192]
# Bin 73: Items [102]
# Bin 74: Items [92]
# Bin 75: Items [189, 217]
# Bin 76: Items [17, 183]
# Bin 77: Items [52, 194]
# Bin 78: Items [47, 216]
# Bin 79: Items [57]
# Bin 80: Items [113, 127]
# Bin 81: Items [110, 190, 195, 215]
# Bin 82: Items [20]
# Bin 83: Items [87, 130]
# Bin 84: Items [91, 126]
# Bin 85: Items [29, 147]
# Bin 86: Items [108]
# Bin 87: Items [89, 167]
# Bin 88: Items [86, 196]
# Bin 89: Items [68, 103, 115]
# Bin 90: Items [94, 199]
# Bin 91: Items [19, 125]
# Bin 92: Items [124, 148]
# Bin 93: Items [131, 146, 248]
# Bin 94: Items [13, 150]
# Bin 95: Items [140, 144]
# Bin 96: Items [176, 193]
# Bin 97: Items [145, 160]
# Bin 98: Items [122, 162, 170, 223]
# Bin 99: Items [128, 198, 227]
#
# Falkenauer_u250_15.txt
# No optimal solution found.
#
# Falkenauer_u250_16.txt
# Optimal solution found!
# Bin 0: Items []
# Bin 1: Items [5, 141]
# Bin 2: Items [28]
# Bin 3: Items []
# Bin 4: Items [114]
# Bin 5: Items [96]
# Bin 6: Items [17]
# Bin 7: Items [21]
# Bin 8: Items [107]
# Bin 9: Items [162]
# Bin 10: Items [29]
# Bin 11: Items []
# Bin 12: Items [195]
# Bin 13: Items [6]
# Bin 14: Items [97]
# Bin 15: Items [77]
# Bin 16: Items [115]
# Bin 17: Items [91]
# Bin 18: Items [104, 130]
# Bin 19: Items [126]
# Bin 20: Items [4]
# Bin 21: Items [95, 170]
# Bin 22: Items [76, 140]
# Bin 23: Items [94]
# Bin 24: Items [16]
# Bin 25: Items [185]
# Bin 26: Items [19]
# Bin 27: Items []
# Bin 28: Items [92]
# Bin 29: Items [70]
# Bin 30: Items []
# Bin 31: Items [103]
# Bin 32: Items [169, 178]
# Bin 33: Items [20]
# Bin 34: Items []
# Bin 35: Items [69]
# Bin 36: Items [168]
# Bin 37: Items [197]
# Bin 38: Items [105]
# Bin 39: Items [93]
# Bin 40: Items [127, 193]
# Bin 41: Items [25, 37]
# Bin 42: Items [75]
# Bin 43: Items [41]
# Bin 44: Items [100, 228]
# Bin 45: Items [53]
# Bin 46: Items [237]
# Bin 47: Items [63, 133]
# Bin 48: Items [101]
# Bin 49: Items [40, 186]
# Bin 50: Items [39]
# Bin 51: Items [90, 161]
# Bin 52: Items [38, 238]
# Bin 53: Items [68]
# Bin 54: Items [121, 129]
# Bin 55: Items [113, 229]
# Bin 56: Items [71, 158]
# Bin 57: Items [132, 176]
# Bin 58: Items [102, 119]
# Bin 59: Items [72, 142]
# Bin 60: Items [99]
# Bin 61: Items [22]
# Bin 62: Items [120]
# Bin 63: Items [98]
# Bin 64: Items [156, 196]
# Bin 65: Items [3]
# Bin 66: Items [64, 152]
# Bin 67: Items [0]
# Bin 68: Items [43]
# Bin 69: Items [52, 194, 245]
# Bin 70: Items [106, 135]
# Bin 71: Items [128, 154]
# Bin 72: Items [118]
# Bin 73: Items [67, 153]
# Bin 74: Items [122, 244]
# Bin 75: Items [42, 134]
# Bin 76: Items [116, 160, 243]
# Bin 77: Items [110, 124]
# Bin 78: Items [111, 177]
# Bin 79: Items [51]
# Bin 80: Items [65, 230]
# Bin 81: Items [143, 231]
# Bin 82: Items [66, 166, 199]
# Bin 83: Items [8, 157]
# Bin 84: Items [1]
# Bin 85: Items [139, 200, 218, 236]
# Bin 86: Items [24]
# Bin 87: Items [61, 212]
# Bin 88: Items [138, 167]
# Bin 89: Items [27]
# Bin 90: Items [88, 159, 214]
# Bin 91: Items [148, 163, 203, 235]
# Bin 92: Items [131, 201]
# Bin 93: Items [164, 165]
# Bin 94: Items [155, 198, 232]
# Bin 95: Items [146, 187, 219]
# Bin 96: Items [189, 202, 246]
#
# Falkenauer_u250_17.txt
# Optimal solution found!
# Bin 0: Items [25]
# Bin 1: Items [65]
# Bin 2: Items [77]
# Bin 3: Items [28]
# Bin 4: Items [239]
# Bin 5: Items [27]
# Bin 6: Items [9]
# Bin 7: Items [5]
# Bin 8: Items [35]
# Bin 9: Items [63]
# Bin 10: Items [76]
# Bin 11: Items [87]
# Bin 12: Items [38, 232]
# Bin 13: Items [29, 171]
# Bin 14: Items [147, 213]
# Bin 15: Items [40]
# Bin 16: Items [144]
# Bin 17: Items [125]
# Bin 18: Items [30]
# Bin 19: Items [109]
# Bin 20: Items [34]
# Bin 21: Items [88]
# Bin 22: Items [19]
# Bin 23: Items [165, 206, 241]
# Bin 24: Items [211]
# Bin 25: Items [173]
# Bin 26: Items [122]
# Bin 27: Items []
# Bin 28: Items [57]
# Bin 29: Items [6, 204]
# Bin 30: Items [31]
# Bin 31: Items [12]
# Bin 32: Items [58]
# Bin 33: Items [64]
# Bin 34: Items [7]
# Bin 35: Items [120, 201]
# Bin 36: Items [41]
# Bin 37: Items [121, 212]
# Bin 38: Items [17]
# Bin 39: Items [20]
# Bin 40: Items [32]
# Bin 41: Items [149]
# Bin 42: Items [37, 249]
# Bin 43: Items [49]
# Bin 44: Items [148]
# Bin 45: Items [86, 124]
# Bin 46: Items [55, 240]
# Bin 47: Items [112]
# Bin 48: Items [48]
# Bin 49: Items [123]
# Bin 50: Items [11]
# Bin 51: Items [23]
# Bin 52: Items [50]
# Bin 53: Items [51]
# Bin 54: Items [13, 233]
# Bin 55: Items [26]
# Bin 56: Items [61, 164]
# Bin 57: Items [119]
# Bin 58: Items [195]
# Bin 59: Items [152, 153]
# Bin 60: Items [33, 186]
# Bin 61: Items [85]
# Bin 62: Items [10, 237]
# Bin 63: Items [47, 202]
# Bin 64: Items [53, 62]
# Bin 65: Items [68, 197]
# Bin 66: Items [193]
# Bin 67: Items [14, 216, 231]
# Bin 68: Items [3, 59]
# Bin 69: Items [39, 227]
# Bin 70: Items [145]
# Bin 71: Items [70, 161]
# Bin 72: Items [150]
# Bin 73: Items [2, 21]
# Bin 74: Items [0, 215, 225]
# Bin 75: Items [167, 203]
# Bin 76: Items [4, 166]
# Bin 77: Items [36, 176]
# Bin 78: Items [69, 111]
# Bin 79: Items [44, 217]
# Bin 80: Items [146, 214]
# Bin 81: Items [8, 234]
# Bin 82: Items [42, 43, 162]
# Bin 83: Items [66]
# Bin 84: Items [114, 168]
# Bin 85: Items [116, 205]
# Bin 86: Items [108, 115]
# Bin 87: Items [117]
# Bin 88: Items [169, 180, 183]
# Bin 89: Items [141, 179, 185, 235]
# Bin 90: Items [151, 172, 223, 224]
# Bin 91: Items [138, 174, 188]
# Bin 92: Items [178, 196, 228]
# Bin 93: Items [129, 182]
# Bin 94: Items [60, 67]
# Bin 95: Items [118, 170, 175]
# Bin 96: Items [181, 194, 218]
# Bin 97: Items [177, 184, 207]
# Bin 98: Items [126]
# Bin 99: Items [198, 208, 226]
#
# Falkenauer_u250_18.txt
# Optimal solution found!
# Bin 0: Items [43]
# Bin 1: Items [92]
# Bin 2: Items [148]
# Bin 3: Items [176]
# Bin 4: Items [45]
# Bin 5: Items [174]
# Bin 6: Items [57]
# Bin 7: Items []
# Bin 8: Items [69, 205]
# Bin 9: Items []
# Bin 10: Items []
# Bin 11: Items [91]
# Bin 12: Items [10]
# Bin 13: Items [82]
# Bin 14: Items [64]
# Bin 15: Items [110]
# Bin 16: Items [44]
# Bin 17: Items [63]
# Bin 18: Items [108]
# Bin 19: Items [55]
# Bin 20: Items [112]
# Bin 21: Items [60]
# Bin 22: Items [98]
# Bin 23: Items [97, 175]
# Bin 24: Items [145]
# Bin 25: Items [137]
# Bin 26: Items [32]
# Bin 27: Items [1, 146]
# Bin 28: Items [65]
# Bin 29: Items [47, 107]
# Bin 30: Items [46, 147]
# Bin 31: Items [62, 187]
# Bin 32: Items [229]
# Bin 33: Items [49]
# Bin 34: Items [90]
# Bin 35: Items [59, 183]
# Bin 36: Items [178, 190]
# Bin 37: Items [33, 228]
# Bin 38: Items [109]
# Bin 39: Items []
# Bin 40: Items [67, 182]
# Bin 41: Items [41]
# Bin 42: Items [113, 231]
# Bin 43: Items [218, 248]
# Bin 44: Items [111]
# Bin 45: Items [217]
# Bin 46: Items [186]
# Bin 47: Items [180, 215]
# Bin 48: Items [58]
# Bin 49: Items [118, 189]
# Bin 50: Items [173, 179]
# Bin 51: Items [53]
# Bin 52: Items [9]
# Bin 53: Items [116]
# Bin 54: Items [51, 239]
# Bin 55: Items [2, 86]
# Bin 56: Items [68]
# Bin 57: Items [61, 117]
# Bin 58: Items [42, 241]
# Bin 59: Items [94, 177]
# Bin 60: Items [93]
# Bin 61: Items [48]
# Bin 62: Items [138, 166]
# Bin 63: Items [149, 153, 240]
# Bin 64: Items [150, 196]
# Bin 65: Items [84, 119]
# Bin 66: Items [103, 232]
# Bin 67: Items [96]
# Bin 68: Items [106, 181]
# Bin 69: Items [81]
# Bin 70: Items [134, 195, 244]
# Bin 71: Items [104, 152, 247]
# Bin 72: Items [11]
# Bin 73: Items [54, 191]
# Bin 74: Items [88]
# Bin 75: Items [95, 184]
# Bin 76: Items [101, 105]
# Bin 77: Items [52, 206]
# Bin 78: Items [13, 243]
# Bin 79: Items [22]
# Bin 80: Items [89, 214]
# Bin 81: Items [79, 167, 249]
# Bin 82: Items [168, 194]
# Bin 83: Items [14, 193]
# Bin 84: Items [197, 242]
# Bin 85: Items [136, 216, 221]
# Bin 86: Items [29]
# Bin 87: Items [4]
# Bin 88: Items [3, 66]
# Bin 89: Items [15, 78]
# Bin 90: Items [5, 185]
# Bin 91: Items [171, 230, 234]
# Bin 92: Items [170, 192]
# Bin 93: Items [50, 188, 220]
# Bin 94: Items [12]
# Bin 95: Items [160, 163]
# Bin 96: Items [77, 198, 238]
# Bin 97: Items [7, 161]
# Bin 98: Items [8, 154, 245]
# Bin 99: Items [162, 164, 165, 237]
#
# Falkenauer_u250_19.txt
# Optimal solution found!
# Bin 0: Items [41]
# Bin 1: Items [217]
# Bin 2: Items [40]
# Bin 3: Items []
# Bin 4: Items []
# Bin 5: Items []
# Bin 6: Items [138]
# Bin 7: Items [99]
# Bin 8: Items [185]
# Bin 9: Items []
# Bin 10: Items [231]
# Bin 11: Items [233]
# Bin 12: Items []
# Bin 13: Items [63]
# Bin 14: Items [3]
# Bin 15: Items [61]
# Bin 16: Items [70, 216]
# Bin 17: Items [229]
# Bin 18: Items [47, 220, 238]
# Bin 19: Items [44]
# Bin 20: Items [183]
# Bin 21: Items [234, 239]
# Bin 22: Items [98]
# Bin 23: Items [43]
# Bin 24: Items [27]
# Bin 25: Items [133]
# Bin 26: Items [4, 230]
# Bin 27: Items [42]
# Bin 28: Items [95]
# Bin 29: Items [30]
# Bin 30: Items [25]
# Bin 31: Items [5]
# Bin 32: Items [218]
# Bin 33: Items [128]
# Bin 34: Items [125]
# Bin 35: Items [0]
# Bin 36: Items [160]
# Bin 37: Items []
# Bin 38: Items [221, 245]
# Bin 39: Items [103]
# Bin 40: Items [168, 249]
# Bin 41: Items [1]
# Bin 42: Items [126]
# Bin 43: Items [161]
# Bin 44: Items [46]
# Bin 45: Items [127]
# Bin 46: Items [26]
# Bin 47: Items [112, 237]
# Bin 48: Items [97]
# Bin 49: Items [180, 182]
# Bin 50: Items [84]
# Bin 51: Items [215]
# Bin 52: Items []
# Bin 53: Items [102, 204]
# Bin 54: Items [29, 53]
# Bin 55: Items [175]
# Bin 56: Items [82]
# Bin 57: Items [59]
# Bin 58: Items []
# Bin 59: Items [96]
# Bin 60: Items [45, 184]
# Bin 61: Items [83]
# Bin 62: Items [52, 121]
# Bin 63: Items [181]
# Bin 64: Items [174]
# Bin 65: Items [232]
# Bin 66: Items [135, 136]
# Bin 67: Items [122]
# Bin 68: Items [101, 164]
# Bin 69: Items [120, 144]
# Bin 70: Items [100, 177, 236]
# Bin 71: Items [111]
# Bin 72: Items [73, 235, 246]
# Bin 73: Items [166, 248]
# Bin 74: Items [104, 179, 198]
# Bin 75: Items [169, 171]
# Bin 76: Items [48]
# Bin 77: Items [187, 192]
# Bin 78: Items [134, 162]
# Bin 79: Items [60, 165]
# Bin 80: Items [137]
# Bin 81: Items [145, 186, 195]
# Bin 82: Items [110]
# Bin 83: Items [163, 188]
# Bin 84: Items [55, 124]
# Bin 85: Items [37]
# Bin 86: Items [146, 191, 197]
# Bin 87: Items [65, 87, 228]
# Bin 88: Items []
# Bin 89: Items [51, 202]
# Bin 90: Items [130, 147, 149]
# Bin 91: Items [129, 173, 247]
# Bin 92: Items [206]
# Bin 93: Items [167, 189]
# Bin 94: Items [57]
# Bin 95: Items [119]
# Bin 96: Items [114, 140]
# Bin 97: Items [190, 193, 209, 210]
# Bin 98: Items [113, 224]
# Bin 99: Items [93, 123]
# Bin 100: Items [148, 203, 241]
# Bin 101: Items [196, 208, 219]

# %%
for file_name,file_data in data.items():
  print(f"{file_name}")
  c=file_data['capacity']
  #print(f"Item weights: {file_data['weights']}")
  b=file_data['weights']
  r1,r2 = first_fit_dec(len(b),c,b)
  print(r1)
  # print(r1,r2)
  # result = bin_packing_ffd(b, c, r1, r2)
  # if result:
  #     for bin_num, items in result.items():
  #         print(f"Bin {bin_num}: Items {items}")
  print("\n\n")
# Out:
# Falkenauer_u250_00.txt
